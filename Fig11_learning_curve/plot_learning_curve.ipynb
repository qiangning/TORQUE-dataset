# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,5))
plt.rcParams.update({'font.size': 14})
plt.plot([10,30,50,100],[35, 53.9, 73.7, 75.2], 'ro-')
plt.plot([10,30,50,100],[35, 35.4, 47.6, 51.1], 'b*-')
plt.plot([10,30,50,100],[4.1,16,33.2,34.5], 'ks-')
plt.plot([0,110],[95.3,95.3], 'r--')
plt.plot([0,110],[84.5,84.5], 'b--')
plt.plot([0,110],[82.5,82.5], 'k--')
plt.ylabel('Performance %')
plt.xlabel('% of Training Set')
plt.title('RoBERTa-large')
plt.grid(True)
plt.legend(['RoBERTa F1','RoBERTa EM','RoBERTa C'],loc='lower right')
plt.xticks([10,30,50,100])
plt.xlim(5,105)
plt.ylim(0,100)
plt.tight_layout()

plt.savefig('./learning_curve.pdf')
plt.show()
